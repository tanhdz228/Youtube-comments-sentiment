# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# Cấu hình API
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyClOBQnILrKS_xHq6TxXhSQSOMQONXU3v8"

youtube = build(api_service_name, api_version, developerKey=DEVELOPER_KEY)

def get_video_ids(channel_id):
    """
    Lấy danh sách tất cả ID video từ một kênh.
    """
    video_ids = []
    try:
        response = youtube.channels().list(
            part="contentDetails",
            id=channel_id
        ).execute()

        if 'items' in response and len(response['items']) > 0:
            uploads_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        else:
            print("Không tìm thấy thông tin kênh. Vui lòng kiểm tra channel_id.")
            return []

        next_page_token = None
        while True:
            playlist_response = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=uploads_playlist_id,
                maxResults=50,
                pageToken=next_page_token
            ).execute()

            for item in playlist_response.get('items', []):
                video_ids.append(item['contentDetails']['videoId'])

            next_page_token = playlist_response.get('nextPageToken')
            if not next_page_token:
                break

    except HttpError as e:
        print(f"Lỗi HTTP xảy ra: {e}")

    return video_ids

def get_comments(video_id):
    """
    Lấy bình luận từ một video cụ thể.
    """
    comments = []
    try:
        next_page_token = None
        while True:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=1000,
                pageToken=next_page_token
            ).execute()

            for item in response.get('items', []):
                comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comments.append(comment)

            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break
    except HttpError as e:
        print(f"Lỗi HTTP xảy ra: {e}")

    return comments

def get_channel_comments(channel_id):
    """
    Lấy bình luận từ tất cả video trên một kênh.
    """
    all_comments = []
    video_ids = get_video_ids(channel_id)

    for video_id in video_ids:
        print(f"Đang lấy bình luận cho video ID: {video_id}")
        comments = get_comments(video_id)
        all_comments.extend(comments)

    return all_comments

# Thay bằng ID của kênh mà bạn muốn lấy bình luận
channel_id = "UCckPYr9b_iVucz8ID1Q67sw"

# Lấy tất cả bình luận từ kênh
channel_comments = get_channel_comments(channel_id)

# In ra bình luận
for comment in channel_comments:
    print(comment)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Here when vid had 2 likes I made it 3
# why it&#39;s look like a mobile game !! what a run
# Riot devs stole that xenohunter right click from this times&#39; normal knife&#39;s right click huh didnt they
# Watching in nov , 2023 😂 🤌
# it cant be the same game wtf
# im watching in &#39;23
# It’s been in the game since beta 💀
# how are load times worse now
# valorant was so goofy back them i love it
# Holy only time I ll ever be better than tenz
# Its the end of 2023 now- dam this looks so much- fun-
# Somebody else got this prehistoric footage randomly recommended?
# Huh
# Watching October 2023, this is WILD
# this just got recommended to me now in october 2023 wth
# Nahh why did i buy xeno when i could just buy prism😭
# TenZ could go back to C9, no?
# Bro I’m watching this October 2023 this is crazy old
# old split
# i cant believe how bad val looked in 2020, i do NOT remember looking this awful
# ...

# %%
import googleapiclient.discovery
import pandas as pd

# Cấu hình API
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyClOBQnILrKS_xHq6TxXhSQSOMQONXU3v8"

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=DEVELOPER_KEY)

def get_video_ids(channel_id):
    """
    Lấy danh sách tất cả video ID từ một kênh YouTube.
    """
    video_ids = []
    try:
        # Lấy ID danh sách phát "uploads" của kênh
        response = youtube.channels().list(
            part="contentDetails",
            id=channel_id
        ).execute()

        if 'items' in response and len(response['items']) > 0:
            uploads_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        else:
            print("Không tìm thấy thông tin kênh. Vui lòng kiểm tra channel_id.")
            return []

        # Duyệt qua danh sách phát để lấy video IDs
        next_page_token = None
        while True:
            playlist_response = youtube.playlistItems().list(
                part="contentDetails",
                playlistId=uploads_playlist_id,
                maxResults=50,
                pageToken=next_page_token
            ).execute()

            for item in playlist_response.get('items', []):
                video_ids.append(item['contentDetails']['videoId'])

            next_page_token = playlist_response.get('nextPageToken')
            if not next_page_token:
                break
    except Exception as e:
        print(f"Lỗi khi lấy video IDs: {e}")

    return video_ids

def get_comments(video_id):
    """
    Lấy bình luận từ một video cụ thể.
    """
    comments = []
    next_page_token = None
    while True:
        try:
            response = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=1000,
                pageToken=next_page_token
            ).execute()

            for item in response.get('items', []):
                comment = item['snippet']['topLevelComment']['snippet']
                comments.append([
                    comment['authorDisplayName'],
                    comment['publishedAt'],
                    comment['updatedAt'],
                    comment['likeCount'],
                    comment['textDisplay'],
                    video_id
                ])

            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break
        except Exception as e:
            print(f"Lỗi khi lấy bình luận từ video {video_id}: {e}")
            break

    return comments

def get_channel_comments(channel_id):
    """
    Lấy tất cả bình luận từ một kênh YouTube.
    """
    all_comments = []
    video_ids = get_video_ids(channel_id)
    for video_id in video_ids:
        print(f"Đang lấy bình luận cho video ID: {video_id}")
        comments = get_comments(video_id)
        all_comments.extend(comments)
    return all_comments

# Thay bằng ID của kênh bạn muốn lấy bình luận
channel_id = "UCckPYr9b_iVucz8ID1Q67sw"

# Lấy tất cả bình luận và chuyển thành DataFrame
comments = get_channel_comments(channel_id)
df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text', 'video_id'])

# Hiển thị 10 dòng đầu tiên
print(df.to_string())

# Xuất ra file CSV nếu cần
df.to_csv('channel_comments.csv', index=False, encoding='utf-8')
# Out:
# Đang lấy bình luận cho video ID: xsEp8526FVY
# Đang lấy bình luận cho video ID: u2XRG9UucUY
# Đang lấy bình luận cho video ID: NffW8QkQ2Rs
# Đang lấy bình luận cho video ID: b7KWLAFvAB8
# Đang lấy bình luận cho video ID: 27c9wcoXeC8
# Đang lấy bình luận cho video ID: CuxYcmoPjQE
# Đang lấy bình luận cho video ID: enujLTa4Jp8
# Đang lấy bình luận cho video ID: eShveRNnSwY
# Đang lấy bình luận cho video ID: 2WC-4uw6NLM
# Đang lấy bình luận cho video ID: stio5_exrTQ
# Đang lấy bình luận cho video ID: 8MJqYWPs2Uo
# Đang lấy bình luận cho video ID: 2Zx9MhoGzi8
# Đang lấy bình luận cho video ID: Ah8qWWP7Weo
# Đang lấy bình luận cho video ID: bOeWtzvBBlg
# Đang lấy bình luận cho video ID: uzba_LiDtYQ
# Đang lấy bình luận cho video ID: G3XRLgXvqoU
# Đang lấy bình luận cho video ID: 5b86h1k_xbE
# Đang lấy bình luận cho video ID: 4XEm7Rt7bW0
# Đang lấy bình luận cho video ID: Z-D-KfBuquI
# Đang lấy bình luận cho video ID: yoBS15AswXM
# Đang lấy bình luận cho video ID: 8aB8zfSLEpc
# ...

# %%
from google.colab import auth
import gspread
from gspread_dataframe import set_with_dataframe
from google.auth import default

# Đăng nhập Google Sheets
auth.authenticate_user()

# Lấy credentials và project ID
credentials, project = default()

# Sử dụng gspread để kết nối với Google Sheets
gc = gspread.authorize(credentials)

# Tạo một Google Sheet mới và xuất dữ liệu
spreadsheet = gc.create('YouTube Comments')
worksheet = spreadsheet.get_worksheet(0)

# Xuất DataFrame vào Google Sheets
set_with_dataframe(worksheet, df)
# In ra đường link của Google Sheets
print(f"Google Sheets đã được tạo. Bạn có thể xem dữ liệu tại: {spreadsheet.url}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9973227345bc> in <cell line: 20>()
#      18
#      19 # Xuất DataFrame vào Google Sheets
# ---> 20 set_with_dataframe(worksheet, df)
#      21 # In ra đường link của Google Sheets
#      22 print(f"Google Sheets đã được tạo. Bạn có thể xem dữ liệu tại: {spreadsheet.url}")
#
# NameError: name 'df' is not defined
